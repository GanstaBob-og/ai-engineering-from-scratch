# %%
import numpy as np
import random

# %%
# %timeit [random.random() for _ in range(100000)]
# Out:
# 6.07 ms ± 157 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.random.rand(100000)
# Out:
# 555 μs ± 49 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
